# %%
import geopandas as gpd

# %%
import pandas as pd

# %%
# check all rows one by one
pd.set_option('display.max_rows', None)

# %%
crime_data_homicide = pd.read_excel('data/crime_data.xlsx',sheet_name= 'Sheet 1')
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
crime_data_homicide.head()
# Out:
#   Data extracted on 08/07/2023 19:56:41 from [ESTAT]  \
# 0                                          Dataset:
# 1                                     Last updated:
# 2                                                NaN
# 3                                     Time frequency
# 4                                    Unit of measure
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0  Crimes recorded by the police by NUTS 3 region...        NaN        NaN
# 1                                   17/09/2015 23:00        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN     Annual        NaN
# 4                                                NaN     Number        NaN

# %%
crime_data_homicide_headers = crime_data_homicide.iloc[7:]

# %%
crime_data_homicide_headers.head()
# Out:
#    Data extracted on 08/07/2023 19:56:41 from [ESTAT] Unnamed: 1 Unnamed: 2  \
# 7                                                TIME       2008       2009
# 8                                        GEO (Labels)        NaN        NaN
# 9                                             Belgium      202.0      186.0
# 10  Région de Bruxelles-Capitale/Brussels Hoofdste...       44.0       33.0
# 11  Région de Bruxelles-Capitale/Brussels Hoofdste...       44.0       33.0
#
#    Unnamed: 3
# 7        2010
# 8         NaN
# 9       184.0
# 10       30.0
# 11       30.0

# %% [markdown]
# first column if for region, second for 2008, third 2009 and fourth 2010

# %%
#rename columns
crime_data_homicide_headers = crime_data_homicide.iloc[9:]

# %%
crime_data_homicide_headers.head()
# Out:
#    Data extracted on 08/07/2023 19:56:41 from [ESTAT] Unnamed: 1 Unnamed: 2  \
# 9                                             Belgium      202.0      186.0
# 10  Région de Bruxelles-Capitale/Brussels Hoofdste...       44.0       33.0
# 11  Région de Bruxelles-Capitale/Brussels Hoofdste...       44.0       33.0
# 12  Arr. de Bruxelles-Capitale/Arr. Brussel-Hoofdstad       44.0       33.0
# 13                                      Vlaams Gewest       83.0       88.0
#
#    Unnamed: 3
# 9       184.0
# 10       30.0
# 11       30.0
# 12       30.0
# 13       71.0

# %%
crime_data_homicide_headers = crime_data_homicide_headers.rename(columns={'Data extracted on 08/07/2023 19:56:41 from [ESTAT]': 'region',
                                'Unnamed: 1': 2008, 'Unnamed: 2': 2009, 'Unnamed: 3': 2010})

# %%
crime_data_homicide_headers.tail()
# Out:
#              region           2008  2009 2010
# 1458         Sirnak            7.0  20.0  9.0
# 1459          Siirt            9.0  15.0  7.0
# 1460            NaN            NaN   NaN  NaN
# 1461  Special value            NaN   NaN  NaN
# 1462              :  not available   NaN  NaN

# %% [markdown]
# remove last rows

# %%
crime_data_homicide_trimmed = crime_data_homicide_headers.iloc[:-3]
crime_data_homicide_trimmed.tail()
# Out:
#                              region  2008  2009  2010
# 1455  Mardin, Batman, Sirnak, Siirt  57.0  71.0  61.0
# 1456                         Mardin  28.0  23.0  33.0
# 1457                         Batman  13.0  13.0  12.0
# 1458                         Sirnak   7.0  20.0   9.0
# 1459                          Siirt   9.0  15.0   7.0

# %%
crime_data_homicide_v1 = crime_data_homicide_trimmed.dropna()

# %%
crime_data_homicide_v2 = crime_data_homicide_v1.drop_duplicates()

# %%
crime_data_homicide_v2
# Out:
#                                                  region    2008    2009  \
# 9                                               Belgium   202.0   186.0
# 10    Région de Bruxelles-Capitale/Brussels Hoofdste...    44.0    33.0
# 12    Arr. de Bruxelles-Capitale/Arr. Brussel-Hoofdstad    44.0    33.0
# 13                                        Vlaams Gewest    83.0    88.0
# 14                                      Prov. Antwerpen    38.0    36.0
# 15                                       Arr. Antwerpen    25.0    28.0
# 16                                        Arr. Mechelen     8.0     6.0
# 17                                        Arr. Turnhout     5.0     2.0
# 18                                   Prov. Limburg (BE)    16.0    12.0
# 19                             Arr. Hasselt (NUTS 2016)    12.0     6.0
# 20                             Arr. Maaseik (NUTS 2016)     2.0     3.0
# 21                                        Arr. Tongeren     2.0     3.0
# ...

# %%
# remove rows that are not specific regions
crime_data_homicide_v2 = crime_data_homicide_v2[crime_data_homicide_v2['region'] !='Extra-Regio NUTS 1']
crime_data_homicide_v2 = crime_data_homicide_v2[crime_data_homicide_v2['region'] !='Extra-Regio NUTS 2']
crime_data_homicide_v2 = crime_data_homicide_v2[crime_data_homicide_v2['region'] !='Extra-Regio NUTS 3']

# %%
crime_data_homicide_v2
# Out:
#                                                  region    2008    2009  \
# 9                                               Belgium   202.0   186.0
# 10    Région de Bruxelles-Capitale/Brussels Hoofdste...    44.0    33.0
# 12    Arr. de Bruxelles-Capitale/Arr. Brussel-Hoofdstad    44.0    33.0
# 13                                        Vlaams Gewest    83.0    88.0
# 14                                      Prov. Antwerpen    38.0    36.0
# 15                                       Arr. Antwerpen    25.0    28.0
# 16                                        Arr. Mechelen     8.0     6.0
# 17                                        Arr. Turnhout     5.0     2.0
# 18                                   Prov. Limburg (BE)    16.0    12.0
# 19                             Arr. Hasselt (NUTS 2016)    12.0     6.0
# 20                             Arr. Maaseik (NUTS 2016)     2.0     3.0
# 21                                        Arr. Tongeren     2.0     3.0
# ...

# %%
crime_data_robbery = pd.read_excel('data/crime_data.xlsx',sheet_name= 'Sheet 2')
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
crime_data_robbery.head()
# Out:
#   Data extracted on 08/07/2023 19:56:41 from [ESTAT]  \
# 0                                          Dataset:
# 1                                     Last updated:
# 2                                                NaN
# 3                                     Time frequency
# 4                                    Unit of measure
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0  Crimes recorded by the police by NUTS 3 region...        NaN        NaN
# 1                                   17/09/2015 23:00        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN     Annual        NaN
# 4                                                NaN     Number        NaN

# %%
crime_data_burglary = pd.read_excel('data/crime_data.xlsx',sheet_name= 'Sheet 3')
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
crime_data_burglary.head()
# Out:
#   Data extracted on 08/07/2023 19:56:41 from [ESTAT]  \
# 0                                          Dataset:
# 1                                     Last updated:
# 2                                                NaN
# 3                                     Time frequency
# 4                                    Unit of measure
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0  Crimes recorded by the police by NUTS 3 region...        NaN        NaN
# 1                                   17/09/2015 23:00        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN     Annual        NaN
# 4                                                NaN     Number        NaN

# %%
crime_data_vehicle_theft = pd.read_excel('data/crime_data.xlsx',sheet_name= 'Sheet 4')
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
crime_data_vehicle_theft.head()
# Out:
#   Data extracted on 08/07/2023 19:56:41 from [ESTAT]  \
# 0                                          Dataset:
# 1                                     Last updated:
# 2                                                NaN
# 3                                     Time frequency
# 4                                    Unit of measure
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0  Crimes recorded by the police by NUTS 3 region...        NaN        NaN
# 1                                   17/09/2015 23:00        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN     Annual        NaN
# 4                                                NaN     Number        NaN
